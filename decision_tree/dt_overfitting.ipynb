# %% [markdown]
# <a href="https://colab.research.google.com/github/mahabubmamun/Machine-Learning/blob/main/decision_tree/dt_overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# %%
def analyzer(max_depth):
  data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/Social_Network_Ads.csv')
  x = data.iloc[:,2:4].values
  y = data.iloc[:,-1].values

  dtc = DecisionTreeClassifier(max_depth = max_depth)
  dtc.fit(x,y)

  a = np.arange(start = x[:,0].min()-1, stop = x[:,0].max()+1, step = 0.1)
  b = np.arange(start = x[:,1].min()-1, stop = x[:,1].max()+1, step = 100)

  xx, yy = np.meshgrid(a,b)
  input_array = np.array([xx.ravel(), yy.ravel()]).T

  labels = dtc.predict(input_array)

  plt.contourf(xx,yy,labels.reshape(xx.shape),alpha = 0.5)
  plt.scatter(x[:,0], x[:,1], c=y)

# %% [markdown]
# #Overfitting

# %%
analyzer(max_depth = None)

# %% [markdown]
# #Underfitting

# %%
analyzer(max_depth=1)

# %% [markdown]
# #Almost better spliting

# %%
analyzer(max_depth=4)
